# %% [markdown]
# <a href="https://colab.research.google.com/github/ovbystrova/Interference/blob/master/Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Interference
#
# ## [Author Verification Using Common N-Gram Profiles of Text Documents](https://www.aclweb.org/anthology/C14-1038.pdf)
# The formulas form the [presentation](https://docs.google.com/presentation/d/1BZhBRqKzosFH2LZMjeQsJ-l_2NAoIszGsNeXn3zk0Z8/edit#slide=id.p) are duplicated in the Class implementation [notebook]((https://github.com/ovbystrova/Interference/blob/master/Class.ipynb)).
#
#
# ### Participants:
# - Bystrova Olga [(ovbystrova)](https://github.com/ovbystrova)
# - Okhapkia Anna [(eischaire)](https://github.com/eischaire)
# - Ryazanskaya Galina [(flying-bear)](https://github.com/flying-bear)
#
#
# ---
# ## The tasks
# Links in the text lead to the notbooks where the mentioned task is done.
# ### Objective
# In the original article the authors had interinsic authorship attribution task as a binary classification: the text was written either by the same author or by someone else. We could have simulated this structure using language background (*LB*) and first (native) language (*FL*) as "authors". However, it would not be ecologically valid, as the texts are, of course, written by different authors, and we did not have the data on authorship. Thus, we changed the task to be binary (for LB) and multiclass (for FL) classification.
#
# ### Pipeline
# 1. [preprocessing](https://github.com/ovbystrova/Interference/blob/master/JSON_Files.ipynb)
#   1. tokenization for word n-grams (of length n)
#   2. truncation so that all texts are of the same length (omitting the shorter texts)
#   3. train/test split  (correcting for imbalanced classes!)
#     1. on FL, native language
#     2. on LB, speaker type
# 3. building classifiers [for each parameter combination](https://github.com/ovbystrova/Interference/blob/master/Class.ipynb)
#   1. calculation of n-gram profiles (P)
#   2. cutoff of the most frequent L
#   3. distance calculation
# 4. multiclass classification with minimal distance for each ensemble, averaging the results
#     1. on FL, [native language](https://github.com/ovbystrova/Interference/blob/master/Language_Testing.ipynb)
#     2. on LB, [speaker type](https://github.com/ovbystrova/Interference/blob/master/LB_Testing.ipynb)
# 5. building [baselines](https://github.com/ovbystrova/Interference/blob/master/Baseline.ipynb)
#   1. TF-IDF + logistic regression
#   2. TF-IDF on word bigrams + logistic regression with parameter search
#   3. word2vec + logistic regression with parameter search
#   4. word2vec + perceptron
# 6. [comparing results](https://github.com/ovbystrova/Interference/blob/master/Report.ipynb)
#
# ### Architectural choices
# - We decided to onbly use ensemble classifiers as they performed the best in the article.
# - We decided to cut all the texts to the length of mode length and omit all texts shorter than that.
# - We decided that we need to balance classes and select the same number of texts from each class, landing on two options - 90 and 400 from each class. All the classes with less datapoints were omitted.
# - Character ensembles were slow and thus were only calculated for LB.
# - We decided to only use the number of n-grams (L) to determine the length of a profile and to use multiclass classification with minimal distance, that does not need a threshold (θ). The parameteres from the original article (the ones we included in bold):
#
# #### **Parameter space**
# - size of N-grams (n)
#     - **from 3 to 10 for characters**
#     - **from 1 to 3 for words**
# - size of a profile
#     - **Number of n-grams (L) 200, 500, 1000, 1500, 2000, 2500, 3000**
#     - Fraction of n-grams from the shortest text (f) from 0.2 to 1 (increments of 0.1)
# - Threshold (θ)
#   - if more than 1 known-author document available (θ2+)
#   - if only 1 known-author document available (θ1)
# - **Ensemble size and parameters**
#
# ## Results
# ### On test
# ![test](https://github.com/ovbystrova/Interference/raw/master/data/on_test.png)
# ### On train (among radius distance models)
# ![train](https://github.com/ovbystrova/Interference/raw/master/data/on_train.png)
# #### Only FL
# ![fl](https://github.com/ovbystrova/Interference/raw/master/data/fl_only.png)
# #### Only LB
# ![lb](https://github.com/ovbystrova/Interference/raw/master/data/lb_only.png)
#
# ## Discussion
# One can see that in ALL cases the simplest baseline model (TF-IDF + logistic regression) outperforms all others.  It is interesting that radius distance method frequently outperforms NN on language background, as NN shows bad results on LB. Another thing to notice is that charachter models are outperformed by word models on train, but not on test. Generally, longer n-grams yeild better results, but the rule also holds more true on train than on test.
#
# The question is why does the radius distance is outperformed by the baseline, the simplest of the models? One could argue it is due to the method being unaplicable for multiclass classification, and being specifically created for intrinsic authorship attribution.
#
# There is another issue connected to this unapplicability. Training each radius distance model took A LOT of time (up to 5 hours) while training logisitic regression and even simple NN took almost no time (under 5 finutes). This is one of the limitations of the radius distance algorithm, as it's complexity and thus time is proportional to the number of distance calculations. This, in turn, is proportional to (1) the number of classes, (2) the number of texts in each class, (3) the profile length. In the article the number of classes was 2 and the number of texts was below 50, which made the time aspect unimportant.
#
# The concusion is that the method might be well-suited for intrinsic authorship attribution, but not for extrinsic authorship attribution, which is essentially multiclass classification that we had.

# %%
import pandas as pd
import numpy as np

# %%
# !wget https://github.com/ovbystrova/Interference/raw/master/data/base_results.csv
# Out:
# --2020-03-29 14:45:23--  https://github.com/ovbystrova/Interference/raw/master/data/base_results.csv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ovbystrova/Interference/master/data/base_results.csv [following]
# --2020-03-29 14:45:23--  https://raw.githubusercontent.com/ovbystrova/Interference/master/data/base_results.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 277 [text/plain]
# Saving to: ‘base_results.csv.2’
#
# base_results.csv.2  100%[===================>]     277  --.-KB/s    in 0s
#
# 2020-03-29 14:45:23 (37.9 MB/s) - ‘base_results.csv.2’ saved [277/277]

# %%
# !wget  https://github.com/ovbystrova/Interference/raw/master/data/LB_results.csv
# Out:
# --2020-03-29 14:45:25--  https://github.com/ovbystrova/Interference/raw/master/data/LB_results.csv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ovbystrova/Interference/master/data/LB_results.csv [following]
# --2020-03-29 14:45:25--  https://raw.githubusercontent.com/ovbystrova/Interference/master/data/LB_results.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1241 (1.2K) [text/plain]
# Saving to: ‘LB_results.csv.2’
#
# LB_results.csv.2    100%[===================>]   1.21K  --.-KB/s    in 0s
#
# 2020-03-29 14:45:25 (239 MB/s) - ‘LB_results.csv.2’ saved [1241/1241]

# %%
! wget https://github.com/ovbystrova/Interference/raw/master/data/FL_results.csv
# Out:
# --2020-03-29 14:45:26--  https://github.com/ovbystrova/Interference/raw/master/data/FL_results.csv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ovbystrova/Interference/master/data/FL_results.csv [following]
# --2020-03-29 14:45:26--  https://raw.githubusercontent.com/ovbystrova/Interference/master/data/FL_results.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 803 [text/plain]
# Saving to: ‘FL_results.csv.2’
#
# FL_results.csv.2    100%[===================>]     803  --.-KB/s    in 0s
#
# 2020-03-29 14:45:26 (189 MB/s) - ‘FL_results.csv.2’ saved [803/803]

# %%
columns = ['train/test', 'class number', 'class length', 'ngram type', 'ngram size', 'accuracy', 'class']

# %%
lb = pd.read_csv('LB_results.csv')
lb['class length'] = 50
lb['class'] = 'language_background'
lb = lb[['Train/Test', 'Class number', 'class length', 'Profile type', 'Profile length',
       'Accuracy score', 'class']]
lb.head()
# Out:
#   Train/Test  Class number  ...  Accuracy score                class
# 0      train             9  ...          0.4875  language_background
# 1      train             9  ...          0.6750  language_background
# 2      train             9  ...          0.6000  language_background
# 3      train             9  ...          0.4875  language_background
# 4      train             9  ...          0.5875  language_background
#
# [5 rows x 7 columns]

# %%
lb.columns = columns
lb.head()
# Out:
#   train/test  class number  ...  accuracy                class
# 0      train             9  ...    0.4875  language_background
# 1      train             9  ...    0.6750  language_background
# 2      train             9  ...    0.6000  language_background
# 3      train             9  ...    0.4875  language_background
# 4      train             9  ...    0.5875  language_background
#
# [5 rows x 7 columns]

# %%
fl = pd.read_csv('FL_results.csv', index_col=0)
fl['class'] = 'native'
fl.head()
# Out:
#   train/test mode  class number  ...  accuracy_score   class
# 0           train             9  ...        0.397222  native
# 1           train             9  ...        0.558333  native
# 2           train             9  ...        0.516667  native
# 3           train             4  ...        0.612500  native
# 4           train             4  ...        0.693750  native
#
# [5 rows x 7 columns]

# %%
fl.columns = columns
fl.head()
# Out:
#   train/test  class number  class length  ... ngram size  accuracy   class
# 0      train             9            50  ...    1-grams  0.397222  native
# 1      train             9            50  ...    2-grams  0.558333  native
# 2      train             9            50  ...    3-grams  0.516667  native
# 3      train             4            50  ...    1-grams  0.612500  native
# 4      train             4            50  ...    2-grams  0.693750  native
#
# [5 rows x 7 columns]

# %%
rows = []
ids = []
jds = []
for i, fl_row in fl.iterrows():
  fl_params = fl_row[:-2]
  row = ['radius distance'] + fl_row[:-1].tolist()
  for j, lb_row in lb.iterrows():
    lb_params = lb_row[:-2]
    if lb_params.tolist() == fl_params.tolist():
      row += [lb_row[-2]]
      rows.append(row)
      ids.append(i)
      jds.append(j)

for i, fl_row in fl.iterrows():
  if i not in ids:
    row = ['radius distance'] + fl_row[:-1].tolist() + [np.nan]
    rows.append(row)

for j, lb_row in lb.iterrows():
  if j not in jds:
    row = ['radius distance'] + lb_row[:-2].tolist() + [np.nan] + [lb_row[-2]]
    rows.append(row)

res = pd.DataFrame(rows, columns=['model', 'train/test', 'class number', 'class length', 'ngram type',
       'ngram size', 'fl', 'lb'])

# %%
res.tail()
# Out:
#               model train/test  class number  ...  ngram size  fl    lb
# 40  radius distance       test             9  ...     9-grams NaN  0.50
# 41  radius distance       test             9  ...    10-grams NaN  0.50
# 42  radius distance       test             4  ...     3-grams NaN  0.50
# 43  radius distance       test             4  ...     4-grams NaN  0.50
# 44  radius distance       test             4  ...     5-grams NaN  0.45
#
# [5 rows x 8 columns]

# %%
def prep(ntype):
  if ntype == 'word':
    return 'regex tokens'
  else:
    return 'None'

# %%
res['preprocess'] = res['ngram type'].apply(prep)
res['vectorize'] = np.nan
res = res[['model', 'train/test', 'class number', 'class length', 'ngram type',
       'ngram size', 'preprocess', 'vectorize', 'fl', 'lb']]

# %%
bs = pd.read_csv('base_results.csv', index_col='id')
bs['class number'] = 15
bs['class length'] = 'full'
bs['train/test'] = 'test'
bs['ngram type'] = np.nan
bs['ngram size'] = np.nan
bs = bs[['model', 'train/test', 'class number', 'class length', 'ngram type','ngram size', 'preprocess', 'vectorize', 'native', 'language_background']]
bs.columns = ['model', 'train/test', 'class number', 'class length', 'ngram type', 'ngram size', 'preprocess', 'vectorize', 'fl', 'lb']
bs.head()
# Out:
#             model train/test  class number  ...     vectorize        fl        lb
# id                                          ...
# 1          logreg       test            15  ...        tf-idf  0.865900  0.889527
# 2   logreg search       test            15  ...        tf-idf  0.821839  0.828863
# 3   logreg search       test            15  ...  w2v bow mean  0.779055  0.772669
# 4     1 linear nn       test            15  ...  w2v bow mean  0.706380  0.757812
#
# [4 rows x 10 columns]

# %%
def strip_g(s):
  if type(s) == str:
    s = s.replace('uni', '1')
    s = s.replace('bi', '2')
    s = s.replace('tri', '3')
    return int(s.strip('-grams'))

# %%
final = pd.concat([res, bs])
final = final.drop_duplicates()
final.index = range(len(final))
final['ngram size'] = final['ngram size'].apply(strip_g)
final.sort_values(['fl', 'lb'], ascending=(False, False))
# Out:
#               model train/test  class number  ...     vectorize        fl        lb
# 45           logreg       test            15  ...        tf-idf  0.865900  0.889527
# 46    logreg search       test            15  ...        tf-idf  0.821839  0.828863
# 47    logreg search       test            15  ...  w2v bow mean  0.779055  0.772669
# 7   radius distance       test             4  ...           NaN  0.750000  0.500000
# 48      1 linear nn       test            15  ...  w2v bow mean  0.706380  0.757812
# 6   radius distance       test             4  ...           NaN  0.700000  0.500000
# 8   radius distance       test             4  ...           NaN  0.700000  0.500000
# 16  radius distance       test             4  ...           NaN  0.700000       NaN
# 10  radius distance      train             4  ...           NaN  0.693750       NaN
# 15  radius distance      train             4  ...           NaN  0.654167       NaN
# 12  radius distance      train             4  ...           NaN  0.646875       NaN
# 14  radius distance      train             4  ...           NaN  0.637500       NaN
# 18  radius distance       test             4  ...           NaN  0.637500       NaN
# 19  radius distance       test             4  ...           NaN  0.616667       NaN
# 9   radius distance      train             4  ...           NaN  0.612500       NaN
# 11  radius distance      train             4  ...           NaN  0.606250       NaN
# 1   radius distance      train             9  ...           NaN  0.558333  0.675000
# 13  radius distance      train             4  ...           NaN  0.554167       NaN
# 17  radius distance       test             4  ...           NaN  0.550000       NaN
# 4   radius distance       test             9  ...           NaN  0.533333  0.450000
# 2   radius distance      train             9  ...           NaN  0.516667  0.600000
# 5   radius distance       test             9  ...           NaN  0.488889  0.550000
# 3   radius distance       test             9  ...           NaN  0.422222  0.500000
# 0   radius distance      train             9  ...           NaN  0.397222  0.487500
# 27  radius distance      train             9  ...           NaN       NaN  0.675000
# 29  radius distance      train             4  ...           NaN       NaN  0.662500
# 25  radius distance      train             9  ...           NaN       NaN  0.650000
# 26  radius distance      train             9  ...           NaN       NaN  0.650000
# 21  radius distance      train             9  ...           NaN       NaN  0.587500
# 24  radius distance      train             9  ...           NaN       NaN  0.587500
# 30  radius distance      train             4  ...           NaN       NaN  0.575000
# 22  radius distance      train             9  ...           NaN       NaN  0.562500
# 23  radius distance      train             9  ...           NaN       NaN  0.562500
# 39  radius distance       test             9  ...           NaN       NaN  0.550000
# 33  radius distance      train             4  ...           NaN       NaN  0.525000
# 31  radius distance      train             4  ...           NaN       NaN  0.500000
# 32  radius distance      train             4  ...           NaN       NaN  0.500000
# 34  radius distance       test             9  ...           NaN       NaN  0.500000
# 35  radius distance       test             9  ...           NaN       NaN  0.500000
# 36  radius distance       test             9  ...           NaN       NaN  0.500000
# 37  radius distance       test             9  ...           NaN       NaN  0.500000
# 38  radius distance       test             9  ...           NaN       NaN  0.500000
# 40  radius distance       test             9  ...           NaN       NaN  0.500000
# 41  radius distance       test             9  ...           NaN       NaN  0.500000
# 42  radius distance       test             4  ...           NaN       NaN  0.500000
# 43  radius distance       test             4  ...           NaN       NaN  0.500000
# 20  radius distance      train             9  ...           NaN       NaN  0.487500
# 28  radius distance      train             4  ...           NaN       NaN  0.487500
# 44  radius distance       test             4  ...           NaN       NaN  0.450000
#
# [49 rows x 10 columns]

# %%
nonan = final[final['fl'].notna() & final['lb'].notna()]
nonan[nonan['train/test'] == 'test'].sort_values(['fl', 'lb'], ascending=(False, False)).style.background_gradient(axis=0, cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row0_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row0_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row0_col8 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row0_col9 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row1_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row1_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row1_col8 {
#             background-color:  #980c13;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row1_col9 {
#             background-color:  #a91016;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row2_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row2_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row2_col8 {
#             background-color:  #bb141a;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row2_col9 {
#             background-color:  #d01d1f;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row3_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row3_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row3_col8 {
#             background-color:  #ce1a1e;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row3_col9 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row4_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row4_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row4_col8 {
#             background-color:  #eb372a;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row4_col9 {
#             background-color:  #d92523;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row5_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row5_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row5_col8 {
#             background-color:  #ee3a2c;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row5_col9 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row6_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row6_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row6_col8 {
#             background-color:  #ee3a2c;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row6_col9 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row7_col2 {
#             background-color:  #fb7858;
#             color:  #000000;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row7_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row7_col8 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row7_col9 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row8_col2 {
#             background-color:  #fb7858;
#             color:  #000000;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row8_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row8_col8 {
#             background-color:  #fed9c9;
#             color:  #000000;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row8_col9 {
#             background-color:  #fcc2aa;
#             color:  #000000;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row9_col2 {
#             background-color:  #fb7858;
#             color:  #000000;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row9_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row9_col8 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8708a76c_71cc_11ea_b12c_0242ac1c0002row9_col9 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }</style><table id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model</th>        <th class="col_heading level0 col1" >train/test</th>        <th class="col_heading level0 col2" >class number</th>        <th class="col_heading level0 col3" >class length</th>        <th class="col_heading level0 col4" >ngram type</th>        <th class="col_heading level0 col5" >ngram size</th>        <th class="col_heading level0 col6" >preprocess</th>        <th class="col_heading level0 col7" >vectorize</th>        <th class="col_heading level0 col8" >fl</th>        <th class="col_heading level0 col9" >lb</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002level0_row0" class="row_heading level0 row0" >45</th>
#                         <td id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002row0_col0" class="data row0 col0" >logreg</td>
#                         <td id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002row0_col1" class="data row0 col1" >test</td>
#                         <td id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002row0_col2" class="data row0 col2" >15</td>
#                         <td id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002row0_col3" class="data row0 col3" >full</td>
#                         <td id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002row0_col4" class="data row0 col4" >nan</td>
#                         <td id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002row0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002row0_col6" class="data row0 col6" >None</td>
#                         <td id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002row0_col7" class="data row0 col7" >tf-idf</td>
#                         <td id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002row0_col8" class="data row0 col8" >0.8659</td>
#                         <td id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002row0_col9" class="data row0 col9" >0.889527</td>
#             </tr>
#             <tr>
#                         <th id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002level0_row1" class="row_heading level0 row1" >46</th>
#                         <td id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002row1_col0" class="data row1 col0" >logreg search</td>
#                         <td id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002row1_col1" class="data row1 col1" >test</td>
#                         <td id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002row1_col2" class="data row1 col2" >15</td>
#                         <td id="T_8708a76c_71cc_11ea_b12c_0242ac1c0002row1_col3" class="data row1 col3" >full</td>

# %%
nonan[nonan['train/test'] == 'train'].sort_values(['fl', 'lb'], ascending=(False, False)).style.background_gradient(axis=0, cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_8ac86306_71cc_11ea_b12c_0242ac1c0002row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8ac86306_71cc_11ea_b12c_0242ac1c0002row0_col5 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_8ac86306_71cc_11ea_b12c_0242ac1c0002row0_col8 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8ac86306_71cc_11ea_b12c_0242ac1c0002row0_col9 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8ac86306_71cc_11ea_b12c_0242ac1c0002row1_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8ac86306_71cc_11ea_b12c_0242ac1c0002row1_col5 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8ac86306_71cc_11ea_b12c_0242ac1c0002row1_col8 {
#             background-color:  #ce1a1e;
#             color:  #f1f1f1;
#         }    #T_8ac86306_71cc_11ea_b12c_0242ac1c0002row1_col9 {
#             background-color:  #f14432;
#             color:  #f1f1f1;
#         }    #T_8ac86306_71cc_11ea_b12c_0242ac1c0002row2_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8ac86306_71cc_11ea_b12c_0242ac1c0002row2_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8ac86306_71cc_11ea_b12c_0242ac1c0002row2_col8 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8ac86306_71cc_11ea_b12c_0242ac1c0002row2_col9 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_8ac86306_71cc_11ea_b12c_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model</th>        <th class="col_heading level0 col1" >train/test</th>        <th class="col_heading level0 col2" >class number</th>        <th class="col_heading level0 col3" >class length</th>        <th class="col_heading level0 col4" >ngram type</th>        <th class="col_heading level0 col5" >ngram size</th>        <th class="col_heading level0 col6" >preprocess</th>        <th class="col_heading level0 col7" >vectorize</th>        <th class="col_heading level0 col8" >fl</th>        <th class="col_heading level0 col9" >lb</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8ac86306_71cc_11ea_b12c_0242ac1c0002level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T
col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_e7679b54_71cc_11ea_b12c_0242ac1c0002row10_col5 {
#             background-color:  #fcaf93;
#             color:  #000000;
#         }    #T_e7679b54_71cc_11ea_b12c_0242ac1c0002row10_col8 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model</th>        <th class="col_heading level0 col1" >train/test</th>        <th class="col_heading level0 col2" >class number</th>        <th class="col_heading level0 col3" >class length</th>        <th class="col_heading level0 col4" >ngram type</th>        <th class="col_heading level0 col5" >ngram size</th>        <th class="col_heading level0 col6" >preprocess</th>        <th class="col_heading level0 col7" >vectorize</th>        <th class="col_heading level0 col8" >lb</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002level0_row0" class="row_heading level0 row0" >39</th>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row0_col0" class="data row0 col0" >radius distance</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row0_col1" class="data row0 col1" >test</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row0_col2" class="data row0 col2" >9</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row0_col3" class="data row0 col3" >50</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row0_col4" class="data row0 col4" >character</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row0_col5" class="data row0 col5" >8</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row0_col6" class="data row0 col6" >None</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row0_col7" class="data row0 col7" >nan</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row0_col8" class="data row0 col8" >0.55</td>
#             </tr>
#             <tr>
#                         <th id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002level0_row1" class="row_heading level0 row1" >34</th>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row1_col0" class="data row1 col0" >radius distance</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row1_col1" class="data row1 col1" >test</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row1_col2" class="data row1 col2" >9</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row1_col3" class="data row1 col3" >50</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row1_col4" class="data row1 col4" >character</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row1_col5" class="data row1 col5" >3</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row1_col6" class="data row1 col6" >None</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row1_col7" class="data row1 col7" >nan</td>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row1_col8" class="data row1 col8" >0.5</td>
#             </tr>
#             <tr>
#                         <th id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002level0_row2" class="row_heading level0 row2" >35</th>
#                         <td id="T_e7679b54_71cc_11ea_b12c_0242ac1c0002row2_col0" class="data row2 col0" >radius distance</td>
#                         <td id="T_f307a404_71cc_11ea_b12c_0242ac1c0002row1_col8" class="data row1 col8" >0.65</td>
#             </tr>
#             <tr>
#                         <th id="T_f307a404_71cc_11ea_b12c_0242ac1c0002level0_row2" class="row_heading level0 row2" >26</th>
#                         <td id="T_f307a404_71cc_11ea_b12c_0242ac1c0002row2_col0" class="data row2 col0" >radius distance</td>
#                         <td id="T_f307a404_71cc_11ea_b12c_0242ac1c0002row2_col1" class="data row2 col1" >train</td>
#                         <td id="T_f307a404_71cc_11ea_b12c_0242ac1c0002row2_col2" class="data row2 col2" >9</td>

# %%
final_lb_w = final_lb[final_lb['ngram type'] == 'word']
final_lb_w[final_lb_w['train/test'] == 'test'].sort_values(['lb'], ascending=False).style.background_gradient(axis=0, cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row0_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row0_col5 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row0_col8 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row1_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row1_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row1_col8 {
#             background-color:  #fb6b4b;
#             color:  #000000;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row2_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row2_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row2_col8 {
#             background-color:  #fb6b4b;
#             color:  #000000;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row3_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row3_col5 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row3_col8 {
#             background-color:  #fb6b4b;
#             color:  #000000;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row4_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row4_col5 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row4_col8 {
#             background-color:  #fb6b4b;
#             color:  #000000;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row5_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row5_col5 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_074ff6e6_71cd_11ea_b12c_0242ac1c0002row5_col8 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_074ff6e6_71cd_11ea_b12c_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model</th>        <th class="col_heading level0 col1" >train/test</th>        <th class="col_heading level0 col2" >class number</th>        <th class="col_heading level0 col3" >class length</th>        <th class="col_heading level0 col4" >ngram type</th>        <th class="col_heading level0 col5" >ngram size</th>        <th class="col_heading level0 col6" >preprocess</th>        <th class="col_heading level0 col7" >vectorize</th>        <th class="col_heading level0 col8" >lb</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T
{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_13faa044_71cd_11ea_b12c_0242ac1c0002row5_col8 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_13faa044_71cd_11ea_b12c_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model</th>        <th class="col_heading level0 col1" >train/test</th>        <th class="col_heading level0 col2" >class number</th>        <th class="col_heading level0 col3" >class length</th>        <th class="col_heading level0 col4" >ngram type</th>        <th class="col_heading level0 col5" >ngram size</th>        <th class="col_heading level0 col6" >preprocess</th>        <th class="col_heading level0 col7" >vectorize</th>        <th class="col_heading level0 col8" >lb</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_13faa044_71cd_11ea_b12c_0242ac1c0002level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row0_col0" class="data row0 col0" >radius distance</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row0_col1" class="data row0 col1" >train</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row0_col2" class="data row0 col2" >9</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row0_col3" class="data row0 col3" >50</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row0_col4" class="data row0 col4" >word</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row0_col5" class="data row0 col5" >2</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row0_col6" class="data row0 col6" >regex tokens</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row0_col7" class="data row0 col7" >nan</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row0_col8" class="data row0 col8" >0.675</td>
#             </tr>
#             <tr>
#                         <th id="T_13faa044_71cd_11ea_b12c_0242ac1c0002level0_row1" class="row_heading level0 row1" >29</th>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row1_col0" class="data row1 col0" >radius distance</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row1_col1" class="data row1 col1" >train</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row1_col2" class="data row1 col2" >4</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row1_col3" class="data row1 col3" >50</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row1_col4" class="data row1 col4" >word</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row1_col5" class="data row1 col5" >2</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row1_col6" class="data row1 col6" >regex tokens</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row1_col7" class="data row1 col7" >nan</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row1_col8" class="data row1 col8" >0.6625</td>
#             </tr>
#             <tr>
#                         <th id="T_13faa044_71cd_11ea_b12c_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row2_col0" class="data row2 col0" >radius distance</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row2_col1" class="data row2 col1" >train</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row2_col2" class="data row2 col2" >9</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row2_col3" class="data row2 col3" >50</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row2_col4" class="data row2 col4" >word</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row2_col5" class="data row2 col5" >3</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row2_col6" class="data row2 col6" >regex tokens</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row2_col7" class="data row2 col7" >nan</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row2_col8" class="data row2 col8" >0.6</td>
#             </tr>
#             <tr>
#                         <th id="T_13faa044_71cd_11ea_b12c_0242ac1c0002level0_row3" class="row_heading level0 row3" >30</th>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row3_col0" class="data row3 col0" >radius distance</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row3_col1" class="data row3 col1" >train</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row3_col2" class="data row3 col2" >4</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row3_col3" class="data row3 col3" >50</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row3_col4" class="data row3 col4" >word</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row3_col5" class="data row3 col5" >3</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row3_col6" class="data row3 col6" >regex tokens</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row3_col7" class="data row3 col7" >nan</td>
#                         <td id="T_13faa044_71cd_11ea_b12c_0242ac1c0002row3_col8" class="data row3 col8" >0.575</td>
#             </tr>
#             <tr>
#                         <th id="T_13faa044_71cd_11ea_b12c_0242ac1c000

# %%
def make_av_lb(df):
  return np.sum(df.lb.values) / len(df)

def get_best_lb(df):
  return np.max(df.lb.values)

# %% [markdown]
# words

# %%
w_tr = ['train', 'word', get_best_lb(final_lb_w[final_lb_w['train/test'] == 'train']), make_av_lb(final_lb_w[final_lb_w['train/test'] == 'train'])]
w_ts = ['test', 'word', get_best_lb(final_lb_w[final_lb_w['train/test'] == 'test']), make_av_lb(final_lb_w[final_lb_w['train/test'] == 'test'])]

# %% [markdown]
# charachters

# %%
ch_tr = ['train', 'character', get_best_lb(final_lb_ch[final_lb_ch['train/test'] == 'train']), make_av_lb(final_lb_ch[final_lb_ch['train/test'] == 'train'])]
ch_ts = ['test', 'character', get_best_lb(final_lb_ch[final_lb_ch['train/test'] == 'test']), make_av_lb(final_lb_ch[final_lb_ch['train/test'] == 'test'])]

# %%
cols = columns=['train/test', 'ngram type', 'max', 'average']
lb_compare = pd.DataFrame(columns = cols)

# %%
for el in [w_tr, w_ts, ch_tr, ch_ts]:
  lb_compare = lb_compare.append(dict(zip(cols, el)), ignore_index=True)

# %%
lb_compare.sort_values(['max', 'average'], ascending=(False, False)).style.background_gradient(axis=0, cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row0_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row0_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row1_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row1_col3 {
#             background-color:  #a10e15;
#             color:  #f1f1f1;
#         }    #T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row2_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row2_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row3_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row3_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >train/test</th>        <th class="col_heading level0 col1" >ngram type</th>        <th class="col_heading level0 col2" >max</th>        <th class="col_heading level0 col3" >average</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row0_col0" class="data row0 col0" >train</td>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row0_col1" class="data row0 col1" >word</td>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row0_col2" class="data row0 col2" >0.675</td>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row0_col3" class="data row0 col3" >0.58125</td>
#             </tr>
#             <tr>
#                         <th id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row1_col0" class="data row1 col0" >train</td>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row1_col1" class="data row1 col1" >character</td>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row1_col2" class="data row1 col2" >0.675</td>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row1_col3" class="data row1 col3" >0.571591</td>
#             </tr>
#             <tr>
#                         <th id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002level0_row2" class="row_heading level0 row2" >1</th>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row2_col0" class="data row2 col0" >test</td>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row2_col1" class="data row2 col1" >word</td>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row2_col2" class="data row2 col2" >0.55</td>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row2_col3" class="data row2 col3" >0.5</td>
#             </tr>
#             <tr>
#                         <th id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row3_col0" class="data row3 col0" >test</td>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row3_col1" class="data row3 col1" >character</td>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row3_col2" class="data row3 col2" >0.55</td>
#                         <td id="T_0f5b5720_71cf_11ea_b12c_0242ac1c0002row3_col3" class="data row3 col3" >0.5</td>
#             </tr>
#     </tbody></table>
